# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data.csv",
                 usecols=['Date', 'open', 'high', 'low', 'close', 'vol'],
                 parse_dates=['Date'],
                 index_col=['Date'],)
data.head(10)
# Out:
#              open   high    low  close   vol
# Date
# 2012-01-01  873.0  879.0  851.0  879.0   799
# 2012-01-02  879.0  913.0  882.0  900.0  1002
# 2012-01-03  900.0  916.0  892.0  892.0  2653
# 2012-01-04  892.0  875.0  842.0  865.0   490
# 2012-01-05  865.0  875.0  858.0  858.0   121
# 2012-01-08  858.0  845.0  814.0  830.0  4835
# 2012-01-09  830.0  846.0  830.0  846.0   195
# 2012-01-10  858.0  862.0  845.0  845.0   658
# 2012-01-11  845.0  874.0  845.0  874.0   969
# 2012-01-12  874.0  904.0  860.0  904.0   773

# %%
data.isnull().sum() #checking for nullity
# Out:
# open     0
# high     0
# low      0
# close    0
# vol      0
# dtype: int64

# %%
def plot_graph(record):      # reusale function for plotting purposes
    plt.figure(figsize=(20,12))
    plt.plot(record)

# %%
plot_graph(data.close)

# %%
data=data[['close']]
data.tail()
# Out:
#             close
# Date
# 2020-03-16  750.0
# 2020-03-17  731.0
# 2020-03-18  715.0
# 2020-03-19  730.0
# 2020-03-22  701.0

# %%
data.close=data.close.resample("W").mean()  #smoothing the data by resampling it in week period
data.dropna(inplace=True)
data.head(10)
# Out:
#                  close
# Date
# 2012-01-01  879.000000
# 2012-01-08  869.000000
# 2012-01-22  864.500000
# 2012-01-29  833.750000
# 2012-02-05  838.250000
# 2012-02-12  835.600000
# 2012-02-26  848.000000
# 2012-03-04  867.200000
# 2012-03-11  883.333333
# 2012-03-18  867.800000

# %% [markdown]
# ### The curve is smoother than the previous one

# %%
plot_graph(data.close)

# %% [markdown]
# ## Cheking for stationarity of time series

# %%
from statsmodels.tsa.stattools import adfuller

#Ho: It is not stationary
#H1: It is stationary

def adfuller_test(records):
    result=adfuller(records)
    labels=['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for label,value in zip(labels,result):
        print(label+" : "+str(value))
    if result[1]<=0.05:
        print("Null hypothesis is rejected. Series is stationary.")
    else:
        print("Null hypothesis is accepted. Series in not stationary.")

# %%
adfuller_test(data.close)
# Out:
# ADF Test Statistic : -1.5935367271274512
# p-value : 0.48683941293703936
# #Lags Used : 2
# Number of Observations Used : 376
# Null hypothesis is accepted. Series in not stationary.

# %%
first_difference=data['close']-data['close'].shift(1)

# %%
adfuller_test(first_difference.dropna())
# Out:
# ADF Test Statistic : -11.510902375472895
# p-value : 4.2623680183832915e-21
# #Lags Used : 1
# Number of Observations Used : 376
# Null hypothesis is rejected. Series is stationary.

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(data['close'].dropna(),lags=60,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(data['close'].dropna(),lags=60,ax=ax2)

# %%
from statsmodels.tsa.arima_model import ARIMA

model=ARIMA(data['close'],order=(10,1,0))
model_fit=model.fit(disp=0)
print(model_fit.summary())
# Out:
# C:\Users\user\anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\user\anaconda3\envs\tensorflow\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                  378
# Model:                ARIMA(10, 1, 0)   Log Likelihood               -2164.964
# Method:                       css-mle   S.D. of innovations             74.308
# Date:                Tue, 25 Aug 2020   AIC                           4353.928
# Time:                        18:51:25   BIC                           4401.147
# Sample:                             1   HQIC                          4372.669
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.4686      4.521     -0.104      0.917      -9.330       8.393
# ar.L1.D.close      0.1478      0.051      2.877      0.004       0.047       0.249
# ar.L2.D.close      0.1040      0.052      2.002      0.045       0.002       0.206
# ar.L3.D.close     -0.0454      0.052     -0.869      0.385      -0.148       0.057
# ar.L4.D.close     -0.0593      0.052     -1.136      0.256      -0.162       0.043
# ar.L5.D.close     -0.0468      0.052     -0.902      0.367      -0.149       0.055
# ar.L6.D.close      0.1050      0.052      2.026      0.043       0.003       0.207
# ar.L7.D.close     -0.0668      0.052     -1.285      0.199      -0.169       0.035
# ar.L8.D.close     -0.0556      0.052     -1.069      0.285      -0.157       0.046
# ar.L9.D.close      0.0569      0.052      1.102      0.271      -0.044       0.158
# ar.L10.D.close     0.0150      0.051      0.294      0.769      -0.085       0.115
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.4571           -0.0000j            1.4571           -0.0000
# AR.2             1.1133           -0.7410j            1.3373           -0.0935
# AR.3             1.1133           +0.7410j            1.3373            0.0935
# AR.4             0.4647           -1.2294j            1.3143           -0.1925
# AR.5             0.4647           +1.2294j            1.3143            0.1925
# AR.6            -0.6065           -1.0965j            1.2531           -0.3304
# AR.7            -0.6065           +1.0965j            1.2531            0.3304
# AR.8            -1.4376           -0.3406j            1.4774           -0.4630
# AR.9            -1.4376           +0.3406j            1.4774            0.4630
# AR.10           -4.3165           -0.0000j            4.3165           -0.5000
# ------------------------------------------------------------------------------

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
residuals.plot(kind='kde')

# %%
residuals.describe()
# Out:
#                 0
# count  378.000000
# mean    -0.001036
# std     74.407249
# min   -437.520401
# 25%    -25.317447
# 50%     -0.978151
# 75%     30.598907
# max    327.571207

# %%
X=data.close.values
len(X)
# Out:
# 379

# %%
size = int(len(X) * 0.66)  #splitting of data into train and test set
train, test = X[0:size], X[size:len(X)]
actual_train = [x for x in train]
predictions=list()

# %%
for t in range(len(test)):
    model = ARIMA(actual_train, order=(10,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    prediction = output[0]
    predictions.append(prediction)
    test_value = test[t]
    actual_train.append(test_value)
    print('%d. predicted=%f, expected=%f'%(t+1,prediction,test_value))
# Out:
# 1. predicted=1606.200079, expected=1637.200000
# 2. predicted=1653.826073, expected=1617.800000
# 3. predicted=1610.546865, expected=1658.000000
# 4. predicted=1663.363737, expected=1764.000000
# 5. predicted=1793.579052, expected=1727.500000
# 6. predicted=1732.981418, expected=1735.000000
# 7. predicted=1733.022079, expected=1667.000000
# 8. predicted=1655.171825, expected=1291.200000
# 9. predicted=1225.735868, expected=1257.333333
# 10. predicted=1225.625050, expected=1242.666667
# 11. predicted=1250.517806, expected=1205.800000
# 12. predicted=1226.682792, expected=1276.750000
# 13. predicted=1308.888744, expected=1246.750000
# 14. predicted=1218.643832, expected=1216.400000
# 15. predicted=1230.482083, expected=1162.800000
# 16. predicted=1162.622557, expected=1182.200000
# 17. predicted=1156.511288, expected=1158.400000
# 18. predicted=1166.976211, expected=1167.000000
# 19. predicted=1164.072003, expected=1159.600000
# 20. predicted=1155.612312, expected=1153.800000
# 21. predicted=1153.454330, expected=1097.250000
# 22. predicted=1095.392136, expected=1072.200000
# 23. predicted=1059.707811, expected=1078.500000
# 24. predicted=1078.566807, expected=1036.000000
# 25. predicted=1036.323783, expected=1034.000000
# 26. predicted=1031.464394, expected=1074.500000
# 27. predicted=1078.137792, expected=1070.000000
# 28. predicted=1076.949899, expected=1086.500000
# 29. predicted=1092.989009, expected=1088.750000
# 30. predicted=1082.450244, expected=1055.250000
# 31. predicted=1047.925653, expected=1047.250000
# 32. predicted=1047.992273, expected=1030.200000
# 33. predicted=1023.578265, expected=949.400000
# 34. predicted=937.874201, expected=965.800000
# 35. predicted=963.798208, expected=989.400000
# 36. predicted=996.294278, expected=1031.600000
# 37. predicted=1047.641481, expected=1033.000000
# 38. predicted=1040.500363, expected=1007.666667
# 39. predicted=990.644889, expected=1000.800000
# 40. predicted=998.560853, expected=992.000000
# 41. predicted=993.565777, expected=998.200000
# 42. predicted=998.444924, expected=975.000000
# 43. predicted=971.591583, expected=953.000000
# 44. predicted=944.918570, expected=941.600000
# 45. predicted=941.849964, expected=929.800000
# 46. predicted=930.442629, expected=924.200000
# 47. predicted=925.224281, expected=917.000000
# 48. predicted=914.575246, expected=904.200000
# 49. predicted=901.004010, expected=902.200000
# 50. predicted=902.747153, expected=906.600000
# 51. predicted=907.448054, expected=904.000000
# 52. predicted=904.308137, expected=933.000000
# 53. predicted=936.556000, expected=944.600000
# 54. predicted=948.102633, expected=948.250000
# 55. predicted=949.021579, expected=967.000000
# 56. predicted=968.640194, expected=966.400000
# 57. predicted=965.201272, expected=964.750000
# 58. predicted=965.713117, expected=960.500000
# 59. predicted=958.756213, expected=940.600000
# 60. predicted=935.176033, expected=931.600000
# 61. predicted=931.397493, expected=953.000000
# 62. predicted=956.581734, expected=954.200000
# 63. predicted=958.425322, expected=943.600000
# 64. predicted=943.572842, expected=931.666667
# 65. predicted=926.179640, expected=916.800000
# 66. predicted=912.863862, expected=904.600000
# 67. predicted=905.738575, expected=882.600000
# 68. predicted=878.360803, expected=855.200000
# 69. predicted=847.837096, expected=851.800000
# 70. predicted=850.867209, expected=858.200000
# 71. predicted=861.846326, expected=865.000000
# 72. predicted=868.994523, expected=847.800000
# 73. predicted=845.184234, expected=835.800000
# 74. predicted=828.949255, expected=843.400000
# 75. predicted=844.094587, expected=840.200000
# 76. predicted=842.507753, expected=836.600000
# 77. predicted=835.514933, expected=828.400000
# 78. predicted=823.839883, expected=819.400000
# 79. predicted=816.579976, expected=792.600000
# 80. predicted=790.834679, expected=712.500000
# 81. predicted=697.377200, expected=687.000000
# 82. predicted=674.353965, expected=713.600000
# 83. predicted=719.973266, expected=716.750000
# 84. predicted=727.041875, expected=711.800000
# 85. predicted=712.696691, expected=722.400000
# 86. predicted=714.861108, expected=792.200000
# 87. predicted=803.825278, expected=878.400000
# 88. predicted=904.525528, expected=851.500000
# 89. predicted=848.318848, expected=845.800000
# 90. predicted=828.563424, expected=846.200000
# 91. predicted=840.732015, expected=838.400000
# 92. predicted=842.506837, expected=839.400000
# 93. predicted=844.869729, expected=821.800000
# 94. predicted=810.560408, expected=812.200000
# 95. predicted=810.594873, expected=801.400000
# 96. predicted=806.770349, expected=790.400000
# 97. predicted=787.858399, expected=810.400000
# 98. predicted=813.707804, expected=805.000000
# 99. predicted=806.306813, expected=805.400000
# 100. predicted=804.331754, expected=800.800000
# 101. predicted=799.531964, expected=790.800000
# 102. predicted=786.864932, expected=781.400000
# 103. predicted=781.366647, expected=777.400000
# 104. predicted=774.447948, expected=772.400000
# 105. predicted=771.060715, expected=773.000000
# 106. predicted=774.192161, expected=769.200000
# 107. predicted=768.549668, expected=761.400000
# 108. predicted=759.697589, expected=758.000000
# 109. predicted=756.940424, expected=761.400000
# 110. predicted=761.295391, expected=760.500000
# 111. predicted=761.119491, expected=763.200000
# 112. predicted=763.072408, expected=751.400000
# 113. predicted=748.713209, expected=745.600000
# 114. predicted=743.065634, expected=728.000000
# 115. predicted=725.494956, expected=726.800000
# 116. predicted=724.615727, expected=743.800000
# 117. predicted=747.533287, expected=747.400000
# 118. predicted=749.780676, expected=687.200000
# 119. predicted=678.234982, expected=685.600000
# 120. predicted=676.216619, expected=719.600000
# 121. predicted=726.408826, expected=743.000000
# 122. predicted=755.431796, expected=740.000000
# 123. predicted=741.473127, expected=731.400000
# 124. predicted=719.122678, expected=731.600000
# 125. predicted=731.241739, expected=722.400000
# 126. predicted=726.496843, expected=759.800000
# 127. predicted=762.182342, expected=875.800000
# 128. predicted=894.259387, expected=782.750000
# 129. predicted=780.432901, expected=725.400000

# %%
from sklearn.metrics import mean_squared_error
import math

error=mean_squared_error(test,predictions)
rmse=math.sqrt(error)
print(f'The mean squared error is {error}')
print(f'The rmse is {rmse}')
# Out:
# The mean squared error is 1992.2938475404508
# The rmse is 44.63511899323727

# %%
rng=data.iloc[250:,:].index
pred=pd.DataFrame(data=predictions[5:],index=rng,columns=['prediction'])

# %% [markdown]
# ## The model worked well in test data

# %%
plt.figure(figsize=(20,12))
plt.plot(data,label="real")
plt.plot(pred,color='red',label='predicted')
plt.legend()

# %% [markdown]
# ## Forecasting closing price for next 20 weeks.
# It is to be kept in mind that as we keep moving in forecasting period(towards the end of 20 weeks period), the       uncertainity in the prediction increases.
#
# I have implemented 2 methods of forecasting:<br/>
# * using forecast() function of ARIMA. <br/>
# * training ARIMA again for next 20 weeks, appending the predicted value in training list.

# %%
forecast_20=model_fit.forecast(steps=20)

# %%
rng_20=pd.date_range(start="2020-03-23",end="2020-08-12",freq='W')
len(rng_20)
# Out:
# 20

# %%
rng_20
# Out:
# DatetimeIndex(['2020-03-29', '2020-04-05', '2020-04-12', '2020-04-19',
#                '2020-04-26', '2020-05-03', '2020-05-10', '2020-05-17',
#                '2020-05-24', '2020-05-31', '2020-06-07', '2020-06-14',
#                '2020-06-21', '2020-06-28', '2020-07-05', '2020-07-12',
#                '2020-07-19', '2020-07-26', '2020-08-02', '2020-08-09'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
forecast=pd.DataFrame(data=forecast_20[0],index=rng_20,columns=['forecast'])
forecast.head(10)
# Out:
#               forecast
# 2020-03-29  780.432901
# 2020-04-05  764.853009
# 2020-04-12  757.380551
# 2020-04-19  758.767985
# 2020-04-26  773.348038
# 2020-05-03  759.552142
# 2020-05-10  761.236342
# 2020-05-17  768.241462
# 2020-05-24  766.332695
# 2020-05-31  766.033864

# %%
from tqdm import tqdm

# %% [markdown]
# ## Method 2

# %%
forecasts=list()
forecast_train=actual_train.copy()
for t in tqdm(range(20)):
    model2 = ARIMA(forecast_train, order=(10,1,0))
    model_fit2 = model2.fit(disp=0)
    output = model_fit2.forecast()
    forecast = output[0]
    forecasts.append(forecast)
    forecast_train.append(forecast)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [04:27<00:00, 13.37s/it]

# %%
sample_forecasted=pd.DataFrame(data=forecasts,index=rng_20,columns=['forecast'])

# %%
sample_forecasted.plot()

# %%
forecast.plot()

# %% [markdown]
# ### The 2nd method seems to be working well. So code in kernels below uses the prediction from this method.
# I have spliced the dataframe to get recent data(>=2019) and concatenated it with predicted value. If concatenation is not to done, there occurs discontinuity in the graph. This is because two different dataframes are plotted, terminating value of 1st and initiating value of 2nd dataframe doesn't coincide at a point resulting in discontinuity.

# %%
recent_data=data["2019":].copy()
recent_data.columns=['forecast']
recent_data.head()
# Out:
#             forecast
# Date
# 2019-01-06     847.8
# 2019-01-13     835.8
# 2019-01-20     843.4
# 2019-01-27     840.2
# 2019-02-03     836.6

# %% [markdown]
# ## Discontinuous Graph

# %%
plt.figure(figsize=(20,12))
plt.plot(recent_data,label="real")
plt.plot(sample_forecasted,color='red',label='forecasted')
plt.legend()

# %%
collective_data=pd.concat([recent_data,sample_forecasted])
collective_data.head()
# Out:
#             forecast
# 2019-01-06     847.8
# 2019-01-13     835.8
# 2019-01-20     843.4
# 2019-01-27     840.2
# 2019-02-03     836.6

# %%
from datetime import datetime
plt.figure(figsize=(20,12))
plt.plot(collective_data)
plt.annotate("Forecast begins here",
             xy= (datetime(2020,3,29), 702),
             arrowprops=dict(arrowstyle="->"),
             xytext=(datetime(2020,3,29), 720))
# Out:
# Text(2020-03-29 00:00:00, 720, 'Forecast begins here')
